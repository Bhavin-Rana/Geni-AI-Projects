# %%
! pip install -U langchain-google-genai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.5/571.5 kB 22.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 kB 11.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.6.0
#     Uninstalling langchain-core-1.6.0:
#       Successfully uninstalled langchain-core-1.6.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ...

# %%
# !pip install -U langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.17
#     Uninstalling langchain-1.3.17:
#       Successfully uninstalled langchain-1.3.17
# ...

# %%
import google.generativeai as genai
from google.colab import userdata

# Fetch using the new underscore-separated name
GOOGLE_API_KEY = userdata.get('Gemini_Api_Key')

# Configure the genai library with your key
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
gemini_model = genai.GenerativeModel("gemini-3.7-flash")

# Define the prompt
prompt_text = " I am opening a new youtube channel so suggest me Unique channel name "

# Generate content using the Gemini model
response = gemini_model.generate_content(prompt_text)

# Print the suggested names
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-3.7-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 18913.58ms
# To give you the most unique name, it helps to know your **niche** (gaming, tech, vlogs, education, etc.). However, here is a list of creative, memorable, and modern YouTube channel names categorized by genre:
#
# ---
#
# ### 1. Modern & Tech / Coding / Future
# *   **ByteSprout**
# *   **Silicon Drift**
# *   **NextGen Logic**
# *   **Pixel & Protocol**
# *   **The Glitch Fix**
# *   **AlgoVibe**
#
# ### 2. Gaming & Streaming
# *   **Respawn Realm**
# *   **Loot & Level**
# *   **QuestForge**
# *   **Stealth Mode On**
# *   **Pixel Vanguard**
# *   **AFK Horizon**
#
# ### 3. Lifestyle, Aesthetic & Daily Vlogs
# *   **The Cozy Edit**
# *   **Unscripted Days**
# *   **Velvet Canvas**
# *   **Golden Hour Vibe**
# *   **Simply Nomad**
# *   **Aura & Living**
#
# ### 4. Facts, Knowledge & Documentaries
# *   **The Curious Node**
# *   **MindSprout**
# ...
